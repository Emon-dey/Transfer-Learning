# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/tcp_work/hdcnn-x-master/src')
# %run -i 'hdcnn_x.py' --dataset PAMAP2 --mode hdcnn --source_epochs 20 --target_epochs 20 --subject_source subject106 --subject_target subject107 --position_source c --position_target c --n_classes 11
# Out:
# Current experiment parameters:
# {'n_channels': 3, 'n_classes': 11, 'batch_size': 32, 'batch_size_eval': 1024, 'window_size': 128, 'window_offset': 8, 'source_epochs': 20, 'target_epochs': 20, 'n_iter': 20000, 'seed': 0, 'log_interval': 100, 'eval_interval': 500, 'gpu': '0', 'mode': 'hdcnn', 'lr_FCs': 0.002, 'lr_FCs_b1': 0.9, 'lr_FCs_b2': 0.999, 'lr_FCt': 0.0002, 'lr_FCt_b1': 0.9, 'lr_FCt_b2': 0.999, 'w_conv1': 0.5, 'w_conv2': 0.05, 'w_conv3': 0.005, 'w_fc1': 0.001, 'w_fc2': 0.0001, 'log': 'default.csv', 'log_train': 'log_train.csv', 'dataset': 'PAMAP2', 'subject_source': 'subject106', 'subject_target': 'subject107', 'position_source': 'c', 'position_target': 'c', 'scaling': True}
# {'batch_size': 32,
#  'batch_size_eval': 1024,
#  'dataset': 'PAMAP2',
#  'eval_interval': 500,
#  'gpu': '0',
#  'log': 'default.csv',
#  'log_interval': 100,
#  'log_train': 'log_train.csv',
#  'lr_FCs': 0.002,
#  'lr_FCs_b1': 0.9,
#  'lr_FCs_b2': 0.999,
#  'lr_FCt': 0.0002,
#  'lr_FCt_b1': 0.9,
# ...

# %% [markdown]
# # New Section
